# %%
import nltk
from nltk.corpus import wordnet as wn
from collections import Counter

# Download necessary resources if not already present
nltk.download('wordnet')
nltk.download('omw-1.4')

def find_related_words(word_root):
    # We'll collect all words related to the given root in a list
    word_list = []
    
    # Search all synsets in WordNet
    for synset in wn.all_synsets():
        # Check each lemma in the synset
        for lemma in synset.lemmas():
            word = lemma.name()
            # Check if the word contains the provided root
            if word_root.lower() in word.lower():
                word_list.append(word.lower())  # Add the word to the list
    
    return word_list

def save_word_list(word_list):
    file_path = "ouput.txt"
    try:
        with open(file_path, "x", encoding="utf-8") as file:
            file.write(str(word_list))
            print(f"txt file '{file_path}' was created ^ ^ ")
    except FileExistsError:
        print("File already exist ⊙﹏⊙ ")
        

def main():
    # Ask the user for a word root
    word_root = input("Enter a word root to search for related words: ").strip()
    
    # Check if the user entered something
    if word_root:
        word_list = find_related_words(word_root)
        
        if word_list:
            # Count word frequencies using Counter from the collections module
            word_frequencies = Counter(word_list)

            save_word_list(word_list)
            
            # Sort words by frequency (most frequent words first)
            sorted_words = sorted(word_frequencies.items(), key=lambda x: x[1], reverse=True)
            
            # Display the sorted results
            print(f"\nWords related to the root '{word_root}' (sorted by popularity):")
            for word, freq in sorted_words:
                print(f"{word}: {freq} occurrences")
        else:
            print(f"\nNo words found related to the root '{word_root}'.")
    else:
        print("You must enter a word root.")

# Run the program
if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package wordnet to /Users/m/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/m/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Enter a word root to search for related words:  bio
# txt file 'ouput.txt' was created ^ ^
#
# Words related to the root 'bio' (sorted by popularity):
# dubious: 3 occurrences
# biology: 3 occurrences
# amphibious: 2 occurrences
# biogenic: 2 occurrences
# biological: 2 occurrences
# bionic: 2 occurrences
# antibiotic: 2 occurrences
# autobiographical: 2 occurrences
# autobiographic: 2 occurrences
# neurobiological: 2 occurrences
# ebionite: 2 occurrences
# dubiously: 2 occurrences
# biogenesis: 2 occurrences
# bioremediation: 2 occurrences
# bioscope: 2 occurrences
# dubiousness: 2 occurrences
# biomass: 2 occurrences
# bioassay: 2 occurrences
# biomedicine: 2 occurrences
# biotechnology: 2 occurrences
# biohazard: 2 occurrences
# aerobiotic: 1 occurrences
# anaerobiotic: 1 occurrences
# amphibiotic: 1 occurrences
# bioluminescent: 1 occurrences
# biovular: 1 occurrences
# symbiotic: 1 occurrences
# nonsymbiotic: 1 occurrences
# biodegradable: 1 occurrences
# abiogenetic: 1 occurrences
# agrobiologic: 1 occurrences
# agrobiological: 1 occurrences
# anabiotic: 1 occurrences
# biocatalytic: 1 occurrences
# biochemical: 1 occurrences
# bioclimatic: 1 occurrences
# biogenetic: 1 occurrences
# biogenous: 1 occurrences
# biogeographic: 1 occurrences
# biogeographical: 1 occurrences
# biologic: 1 occurrences
# biologistic: 1 occurrences
# sociobiologic: 1 occurrences
# sociobiological: 1 occurrences
# biosynthetic: 1 occurrences
# biosystematic: 1 occurrences
# biotitic: 1 occurrences
# biotypic: 1 occurrences
# cryptobiotic: 1 occurrences
# biomedical: 1 occurrences
# semiautobiographical: 1 occurrences
# bionomical: 1 occurrences
# bionomic: 1 occurrences
# macrobiotic: 1 occurrences
# biotic: 1 occurrences
# biographic: 1 occurrences
# biographical: 1 occurrences
# symbiotically: 1 occurrences
# biologically: 1 occurrences
# sociobiologically: 1 occurrences
# biochemically: 1 occurrences
# biont: 1 occurrences
# amphibious_landing: 1 occurrences
# biologism: 1 occurrences
# biological_research: 1 occurrences
# biomedical_cloning: 1 occurrences
# bioterrorism: 1 occurrences
# biological_terrorism: 1 occurrences
# biopiracy: 1 occurrences
# biogeny: 1 occurrences
# biological_defense: 1 occurrences
# biological_defence: 1 occurrences
# biodefense: 1 occurrences
# biodefence: 1 occurrences
# biological_warfare: 1 occurrences
# biological_attack: 1 occurrences
# biologic_attack: 1 occurrences
# bioattack: 1 occurrences
# biological_warfare_defense: 1 occurrences
# biological_warfare_defence: 1 occurrences
# amphibious_demonstration: 1 occurrences
# amphibious_operation: 1 occurrences
# amphibious_assault: 1 occurrences
# probiotic: 1 occurrences
# probiotic_bacterium: 1 occurrences
# probiotic_microflora: 1 occurrences
# probiotic_flora: 1 occurrences
# gobio: 1 occurrences
# genus_gobio: 1 occurrences
# gobio_gobio: 1 occurrences
# embioptera: 1 occurrences
# order_embioptera: 1 occurrences
# embiodea: 1 occurrences
# order_embiodea: 1 occurrences
# symbion_pandora: 1 occurrences
# embiotocidae: 1 occurrences
# family_embiotocidae: 1 occurrences
# amphibious_aircraft: 1 occurrences
# amphibious_vehicle: 1 occurrences
# antibiotic_drug: 1 occurrences
# antineoplastic_antibiotic: 1 occurrences
# biochip: 1 occurrences
# biohazard_suit: 1 occurrences
# biology_lab: 1 occurrences
# biology_laboratory: 1 occurrences
# bio_lab: 1 occurrences
# bioweapon: 1 occurrences
# biological_weapon: 1 occurrences
# bioarm: 1 occurrences
# neobiotic: 1 occurrences
# novobiocin: 1 occurrences
# penicillinase-resistant_antibiotic: 1 occurrences
# biodiversity: 1 occurrences
# bio-assay: 1 occurrences
# biopsy: 1 occurrences
# chorionic_villus_biopsy: 1 occurrences
# needle_biopsy: 1 occurrences
# biofeedback: 1 occurrences
# bioscience: 1 occurrences
# biological_science: 1 occurrences
# biomedical_science: 1 occurrences
# biometrics: 1 occurrences
# biometry: 1 occurrences
# biostatistics: 1 occurrences
# macrobiotics: 1 occurrences
# agrobiology: 1 occurrences
# biogeography: 1 occurrences
# cryobiology: 1 occurrences
# bionomics: 1 occurrences
# exobiology: 1 occurrences
# space_biology: 1 occurrences
# astrobiology: 1 occurrences
# microbiology: 1 occurrences
# molecular_biology: 1 occurrences
# neurobiology: 1 occurrences
# paleobiology: 1 occurrences
# palaeobiology: 1 occurrences
# biochemistry: 1 occurrences
# radiobiology: 1 occurrences
# sociobiology: 1 occurrences
# biophysics: 1 occurrences
# bioclimatology: 1 occurrences
# bionics: 1 occurrences
# bioengineering: 1 occurrences
# biotech: 1 occurrences
# biosystematics: 1 occurrences
# biosystematy: 1 occurrences
# bioethics: 1 occurrences
# biometric_identification: 1 occurrences
# biometric_authentication: 1 occurrences
# biography: 1 occurrences
# autobiography: 1 occurrences
# labiodental_consonant: 1 occurrences
# labiodental: 1 occurrences
# abiotrophy: 1 occurrences
# macrobiotic_diet: 1 occurrences
# biological_group: 1 occurrences
# biotype: 1 occurrences
# biotic_community: 1 occurrences
# biome: 1 occurrences
# antibiosis: 1 occurrences
# biota: 1 occurrences
# biology_department: 1 occurrences
# department_of_biology: 1 occurrences
# biosphere: 1 occurrences
# biogeographical_region: 1 occurrences
# bioko: 1 occurrences
# albion: 1 occurrences
# biological_agent: 1 occurrences
# abiogenist: 1 occurrences
# autobiographer: 1 occurrences
# biochemist: 1 occurrences
# biographer: 1 occurrences
# biologist: 1 occurrences
# biophysicist: 1 occurrences
# bionic_man: 1 occurrences
# bionic_woman: 1 occurrences
# microbiologist: 1 occurrences
# molecular_biologist: 1 occurrences
# neurobiologist: 1 occurrences
# radiobiologist: 1 occurrences
# sociobiologist: 1 occurrences
# maria_luigi_carlo_zenobio_cherubini: 1 occurrences
# abiogenesis: 1 occurrences
# bioelectricity: 1 occurrences
# aerobiosis: 1 occurrences
# bioluminescence: 1 occurrences
# necrobiosis: 1 occurrences
# centaurea_scabiosa: 1 occurrences
# genus_scabiosa: 1 occurrences
# scabious: 1 occurrences
# scabiosa: 1 occurrences
# sweet_scabious: 1 occurrences
# scabiosa_atropurpurea: 1 occurrences
# field_scabious: 1 occurrences
# scabiosa_arvensis: 1 occurrences
# synchytrium_endobioticum: 1 occurrences
# biochemical_mechanism: 1 occurrences
# biosynthesis: 1 occurrences
# catabiosis: 1 occurrences
# biological_process: 1 occurrences
# symbiosis: 1 occurrences
# trophobiosis: 1 occurrences
# anabiosis: 1 occurrences
# cryptobiosis: 1 occurrences
# amebiosis: 1 occurrences
# amoebiosis: 1 occurrences
# necrobiosis_lipoidica: 1 occurrences
# necrobiosis_lipoidica_diabeticorum: 1 occurrences
# biosafety_level: 1 occurrences
# biosafety_level_1: 1 occurrences
# biosafety_level_2: 1 occurrences
# biosafety_level_3: 1 occurrences
# biosafety_level_4: 1 occurrences
# biodegradable_pollution: 1 occurrences
# nonbiodegradable_pollution: 1 occurrences
# biosafety: 1 occurrences
# biotite: 1 occurrences
# biocatalyst: 1 occurrences
# biotin: 1 occurrences
# bioflavinoid: 1 occurrences
# biological_time: 1 occurrences
# biological_clock: 1 occurrences
# biodegrade: 1 occurrences
