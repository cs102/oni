# %%
from d3blocks import D3Blocks

# %%
# Import library
from d3graph import d3graph, vec2adjmat

# %%
# Create example network
source = ['node A','node F','node B','node B','node B','node A','node C','node Z']
target = ['node F','node B','node J','node F','node F','node M','node M','node A']
weight = [5.56, 0.5, 0.64, 0.23, 0.9, 3.28, 0.5, 0.45]

# %%
# Convert to adjacency matrix
adjmat = vec2adjmat(source, target, weight=weight)
# Out:
# [06-01-2026 01:21:23] [d3graph.d3graph] [INFO] Converting source-target into adjacency matrix..
# [06-01-2026 01:21:23] [d3graph.d3graph] [INFO] Making the matrix symmetric..

# %%
# Initialize
d3 = d3graph()

# %%
# Proces adjmat
d3.graph(adjmat)
# Out:
# [06-01-2026 01:21:55] [d3graph.d3graph] [INFO] Set directed=True to see the markers!
# [06-01-2026 01:21:55] [d3graph.d3graph] [INFO] Keep only edges with weight>0
# [06-01-2026 01:21:58] [d3graph.d3graph] [INFO] Converting source-target into adjacency matrix..
# [06-01-2026 01:21:58] [d3graph.d3graph] [INFO] Making the matrix symmetric..
# [06-01-2026 01:21:58] [d3graph.d3graph] [INFO] Converting adjacency matrix into source-target..
# [06-01-2026 01:21:58] [d3graph.d3graph] [INFO] Number of unique nodes: %.0d

# %%
# Plot
d3.show()
# Out:
# [06-01-2026 01:22:11] [d3graph.d3graph] [INFO] Slider range is set to [0, 6]
# [06-01-2026 01:22:11] [d3graph.d3graph] [INFO] Write to path: [/var/folders/ws/ntlttgsj4xxghp91n4rvp7_w0000gn/T/d3graph/79359560.html]
# [06-01-2026 01:22:11] [d3graph.d3graph] [INFO] File already exists and will be overwritten: [/var/folders/ws/ntlttgsj4xxghp91n4rvp7_w0000gn/T/d3graph/79359560.html]

# %%
# Make changes in node properties
d3.set_node_properties(color=adjmat.columns.values, label=['node 1','node 2','node 3','node 4','node 5','node 6','node 7'])
# Out:
# [06-01-2026 01:22:45] [colourmap.colourmap] [INFO] Add transparency to RGB colors (last column)
# [06-01-2026 01:22:45] [d3graph.d3graph] [INFO] Number of unique nodes: %.0d

# %%
# Plot
d3.show(filepath='c://temp/')
# Out:
# [06-01-2026 01:31:21] [d3graph.d3graph] [INFO] Slider range is set to [0, 6]
# [06-01-2026 01:31:21] [d3graph.d3graph] [INFO] Write to path: [/Users/m/lab/c:/temp/d3graph.html]
# [06-01-2026 01:31:21] [d3graph.d3graph] [INFO] File already exists and will be overwritten: [/Users/m/lab/c:/temp/d3graph.html]

# %%
pip list
# Out:
# Package                    Version
# -------------------------- -----------
# absl-py                    2.3.1
# annotated-types            0.7.0
# anyio                      4.11.0
# appdata                    2.2.1
# appnope                    0.1.4
# argon2-cffi                25.1.0
# argon2-cffi-bindings       25.1.0
# arrow                      1.4.0
# asciitree                  0.3.3
# astor                      0.8.1
# asttokens                  3.0.0
# async-lru                  2.0.5
# attrs                      25.4.0
# babel                      2.17.0
# backrefs                   6.0.1
# beautifulsoup4             4.14.2
# bleach                     6.3.0
# blinker                    1.9.0
# blis                       1.3.3
# catalogue                  2.0.10
# certifi                    2025.10.5
# cffi                       2.0.0
# charset-normalizer         3.4.4
# click                      8.3.0
# cloudpathlib               0.23.0
# colorama                   0.4.6
# colourmap                  1.2.1
# comm                       0.2.3
# confection                 0.1.5
# contourpy                  1.3.3
# cryptography               46.0.3
# cycler                     0.12.1
# cymem                      2.0.13
# d3blocks                   1.6.1
# d3graph                    2.6.1
# datazets                   1.1.3
# debugpy                    1.8.17
# decorator                  5.2.1
# defusedxml                 0.7.1
# en_core_web_sm             3.8.0
# et_xmlfile                 2.0.0
# executing                  2.2.1
# fastjsonschema             2.21.2
# Flask                      3.1.2
# fonttools                  4.60.1
# fqdn                       1.5.1
# gast                       0.6.0
# ghp-import                 2.1.0
# grpcio                     1.76.0
# h11                        0.16.0
# h5py                       3.15.1
# html5lib                   1.1
# httpcore                   1.0.9
# httpx                      0.28.1
# idna                       3.11
# ipykernel                  7.1.0
# ipython                    9.6.0
# ipython_pygments_lexers    1.1.1
# ipywidgets                 8.1.8
# ismember                   1.1.0
# isoduration                20.11.0
# itsdangerous               2.2.0
# jedi                       0.19.2
# Jinja2                     3.1.6
# JLDracula                  0.2.0
# joblib                     1.5.2
# json5                      0.12.1
# jsonpickle                 4.1.1
# jsonpointer                3.0.0
# jsonschema                 4.25.1
# jsonschema-specifications  2025.9.1
# jupyter                    1.1.1
# jupyter_client             8.6.3
# jupyter-console            6.6.3
# jupyter_core               5.9.1
# jupyter-events             0.12.0
# jupyter-lsp                2.3.0
# jupyter_server             2.17.0
# jupyter_server_terminals   0.5.3
# jupyterlab                 4.4.10
# jupyterlab_pygments        0.3.0
# jupyterlab_server          2.28.0
# jupyterlab_widgets         3.0.16
# Keras-Applications         1.0.8
# Keras-Preprocessing        1.1.2
# kiwisolver                 1.4.9
# lark                       1.3.1
# lxml                       6.0.2
# Markdown                   3.10
# MarkupSafe                 2.0.1
# matplotlib                 3.10.7
# matplotlib-inline          0.2.1
# mergedeep                  1.3.4
# mistune                    3.1.4
# mkdocs                     1.6.1
# mkdocs-get-deps            0.2.0
# mkdocs-material            9.7.0
# mkdocs-material-extensions 1.3.1
# morphemes                  1.2.0
# murmurhash                 1.0.15
# nbclient                   0.10.2
# nbconvert                  7.16.6
# nbformat                   5.10.4
# nest-asyncio               1.6.0
# networkx                   3.6.1
# nltk                       3.9.2
# notebook                   7.4.7
# notebook_shim              0.2.4
# numpy                      2.3.4
# openpyxl                   3.1.5
# packaging                  25.0
# paginate                   0.5.7
# pandas                     2.3.3
# pandocfilters              1.5.1
# parso                      0.8.5
# pathspec                   0.12.1
# pdfminer.six               20251107
# pdfplumber                 0.11.8
# pexpect                    4.9.0
# pillow                     12.0.0
# pip                        25.3
# platformdirs               4.5.0
# preshed                    3.0.12
# prometheus_client          0.23.1
# prompt_toolkit             3.0.52
# protobuf                   6.33.0
# psutil                     7.1.3
# ptyprocess                 0.7.0
# pure_eval                  0.2.3
# pycparser                  2.23
# pydantic                   2.12.5
# pydantic_core              2.41.5
# Pygments                   2.19.2
# pymdown-extensions         10.17.1
# pyparsing                  3.2.5
# PyPDF2                     3.0.1
# pypdfium2                  5.2.0
# python-dateutil            2.9.0.post0
# python-json-logger         4.0.0
# python-louvain             0.16
# pytz                       2025.2
# pyvis                      0.3.2
# PyYAML                     6.0.3
# pyyaml_env_tag             1.1
# pyzmq                      27.1.0
# referencing                0.37.0
# regex                      2025.10.23
# requests                   2.32.5
# rfc3339-validator          0.1.4
# rfc3986-validator          0.1.1
# rfc3987-syntax             1.1.0
# rpds-py                    0.28.0
# scikit-learn               1.7.2
# scipy                      1.16.3
# seaborn                    0.13.2
# Send2Trash                 1.8.3
# setuptools                 80.9.0
# six                        1.17.0
# smart_open                 7.5.0
# sniffio                    1.3.1
# soupsieve                  2.8
# spacy                      3.8.11
# spacy-legacy               3.0.12
# spacy-loggers              1.0.5
# srsly                      2.5.2
# stack-data                 0.6.3
# tabulate                   0.9.0
# tensorboard                1.12.2
# tensorflow                 1.12.0
# termcolor                  3.2.0
# terminado                  0.18.1
# textblob                   0.19.0
# thinc                      8.3.10
# threadpoolctl              3.6.0
# tinycss2                   1.4.0
# tinydb                     4.8.2
# tornado                    6.5.2
# tqdm                       4.67.1
# traitlets                  5.14.3
# typer-slim                 0.20.0
# typing_extensions          4.15.0
# typing-inspection          0.4.2
# tzdata                     2025.2
# uri-template               1.3.0
# urllib3                    2.5.0
# wasabi                     1.1.3
# watchdog                   6.0.0
# wcwidth                    0.2.14
# weasel                     0.4.3
# webcolors                  25.10.0
# webencodings               0.5.1
# websocket-client           1.9.0
# Werkzeug                   3.1.3
# wheel                      0.45.1
# widgetsnbextension         4.0.15
# wrapt                      2.0.1
# Note: you may need to restart the kernel to use updated packages.
