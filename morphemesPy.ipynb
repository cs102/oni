# %%
from morphemes import Morphemes

# %%
path = "./data"

# %%
m = Morphemes(path)

# %%
print(m.parse("batman"))
# Out:
# {'status': 'FOUND_IN_DATABASE', 'word': 'batman', 'morpheme_count': 2, 'tree': [{'children': [{'text': 'bat', 'type': 'root'}], 'type': 'free'}, {'children': [{'text': 'man', 'type': 'root'}], 'type': 'free'}]}

# %%
print(m.parse("circumference"))
# Out:
# {'status': 'FOUND_IN_DATABASE', 'word': 'circumference', 'morpheme_count': 2, 'tree': [{'children': [{'text': 'circum', 'type': 'prefix'}, {'text': 'ference', 'type': 'root'}], 'type': 'free'}]}

# %%
import spacy

# %%
# Load the small language model for English and assign it to the variable 'nlp'
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

# %%
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Apple PROPN nsubj
# is AUX aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.K. PROPN nsubj
# startup VERB ccomp
# for ADP prep
# $ SYM quantmod
# 1 NUM compound
# billion NUM pobj

# %%
doc = nlp("This is a sentence. This is another sentence.")
assert doc.has_annotation("SENT_START")
for sent in doc.sents:
    print(sent.text)
# Out:
# This is a sentence.
# This is another sentence.

# %%
doc = nlp("I love coffee")
print(doc.vocab.strings["coffee"])  # 3197928453018144401
print(doc.vocab.strings[3197928453018144401])  # 'coffee'
# Out:
# 3197928453018144401
# coffee

# %%
doc = nlp("I love coffee")
for word in doc:
    lexeme = doc.vocab[word.text]
    print(lexeme.text, lexeme.orth, lexeme.shape_, lexeme.prefix_, lexeme.suffix_,
            lexeme.is_alpha, lexeme.is_digit, lexeme.is_title, lexeme.lang_)
# Out:
# I 4690420944186131903 X I I True False True en
# love 3702023516439754181 xxxx l ove True False False en
# coffee 3197928453018144401 xxxx c fee True False False en
