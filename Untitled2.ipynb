# %%
import PyPDF2
import pdfpumbler 
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import PyPDF2
# ----> 2 import pdfpumbler
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'pdfpumbler'
