# %%
from pyvis.network import Network
net = Network(notebook=True)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.

# %%
net.add_node(1, label="Node 1") # node id = 1 and label = Node 1
net.add_node(2) # node id and label = 2

# %%
net.show('nodes.html')
# Out:
# nodes.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="nodes.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# To display this html file in order to interact with the network
from IPython.core.display import display, HTML
display(HTML("nodes.html"))
#You will see two unconnected nodes
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 2
#       1 # To display this html file in order to interact with the network
# ----> 2 from IPython.core.display import display, HTML
#       3 display(HTML("nodes.html"))
#       4 #You will see two unconnected nodes
#
# ImportError: cannot import name 'display' from 'IPython.core.display' (/Users/m/lab/oni/lib/python3.13/site-packages/IPython/core/display.py)
